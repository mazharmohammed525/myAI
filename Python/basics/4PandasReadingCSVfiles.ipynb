# %% [markdown]
# # Pandas
# - Pandas is a popular library in Python used for data analysis and manipulation. It helps you to work with structured data like tables
#
# ### What Pandas is used for
# - Cleaning and preparing data
# - reading/writing data(CSV, excel, databases)
# - Filtering,sorting, and grouping
# - Performing calculations and statics
# - Handling missing values
# - Its Powerful, easy to use and integrates well with other tolls like Numpy,Matplotlib/seaborn(Visualisation),Machine learning libraries
#
# ### Core Data structures
# - Series --> a single columns(1D data)
# - DataFrame --> a table(rows and columns)
# - different operations

# %%
import pandas as pd
import numpy as np
