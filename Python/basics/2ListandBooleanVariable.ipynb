# %% [markdown]
# # Python Data Structures
# - Boolean
# - Boolean and logical operators
# - List
# - Dictionaries
# - Tuples
# - sets

# %% [markdown]
# ## Boolean Variables
# - Boolean Variables are variables that can have only two possible values: True or False
# - A boolean variables answers a yes/no question

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
mystring = "mazhar"
print(mystring)
print(type(mystring))
# Out:
# mazhar
# <class 'str'>

# %%
mystring.isspace()
# Out:
# False

# %%
mystring.isalpha()
# Out:
# True

# %%
mystring.isnumeric()
# Out:
# False

# %%
mystring.count("a")
# Out:
# 2

# %%
mystring.isalpha()
# Out:
# True

# %%
mystring.isnumeric()
# Out:
# False

# %%
mystring1 = 'Mazhar'
mystring2 = 'Mazhar123'

# %%
print(mystring1)
mystring1.isalpha() and mystring2.isalpha()
# Out:
# Mazhar
# False

# %% [markdown]
# # what is List
# - A list is a built-in data type used to store multiple items in a single variable.
# - A list is an ordered, changeable (mutable) collection of values.
# ## Key features of a list
# - Ordered → items have a fixed position (index starts at 0)
# - Mutable → you can change, add, or remove items
# - Allows duplicates → same value can appear more than once
# - Can store different data types → numbers, strings, even other lists

# %%
type([])
# Out:
# list

# %%
listexample = [1,2,3,4,5]
print(listexample)
print(type(listexample))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
mylist = ['AI','is','the','future',1,1,2,3,4.5, 5.5, True,False,None]
print(mylist)
# Out:
# ['AI', 'is', 'the', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None]

# %%
# Indexing
print(mylist[0])

print(mylist[2])

print(mylist[-1])

print(mylist[-2])

print(mylist[1:3])

print(mylist[::-1])

print(mylist[3:])

print(mylist[-1])

print(mylist[-1][0])

print(mylist[-1][-1])
# Out:
# AI
# the
# [10, 20, 'mazhar']
# AgenticAI
# ['is', 'the']
# [[10, 20, 'mazhar'], 'AgenticAI', None, False, True, 5.5, 4.5, 3, 2, 1, 1, 'future', 'the', 'is', 'AI']
# ['future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI', [10, 20, 'mazhar']]
# [10, 20, 'mazhar']
# 10
# mazhar

# %%
mylist.append("AgenticAI")   # it add the specified element at the end of the list
print(mylist)

mylist.append([10,20,"mazhar"])
print(mylist)
# Out:
# ['AI', 'is', 'the', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI']
# ['AI', 'is', 'the', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI', [10, 20, 'mazhar']]

# %%
mylist.pop()
print(mylist)
# Out:
# ['AI', 'is', 'the', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI']

# %%
mylist.insert(3,'PRO')
print(mylist)
# Out:
# ['AI', 'is', 'the', 'PRO', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI', [10, 20, 'mazhar']]

# %%
mylist.reverse()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 mylist.reverse(False)
#
# TypeError: list.reverse() takes no arguments (1 given)

# %%
print(mylist)
# Out:
# [[10, 20, 'mazhar'], 'AgenticAI', None, False, True, 5.5, 4.5, 3, 2, 1, 1, 'future', 'PRO', 'the', 'is', 'AI']

# %%
mylist.reverse()
print(mylist)
# Out:
# ['AI', 'is', 'the', 'PRO', 'future', 1, 1, 2, 3, 4.5, 5.5, True, False, None, 'AgenticAI', [10, 20, 'mazhar']]

# %%
mylist.sort()  ## becuase of the Hetorogenous elements, list should either numeric and apla
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 mylist.sort()  ## becuase of the Hetorogenous elements, list should either numeric and apla
#       2 print(mylist)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
