# %%
print('Welcome to UV env')
# Out:
# Welcome to UV env

# %%
print('test')
# Out:
# test

# %%
print('test1')
# Out:
# test1

# %%
print('test123')
# Out:
# test123

# %%
print('test in My AI')
# Out:
# test in My AI

# %%
print(2+3)
# Out:
# 5
