# %% [markdown]
# - In langchain, we call them as document loader, they load files like PDF, DOCX, csv, test, HTML and JSON.
# - we may use parser libraries like pypdf,

# %%
from langchain_community.document_loaders import (
TextLoader,
PyPDFLoader,
CSVLoader,
Docx2txtLoader,
UnstructuredCHMLoader,
JSONLoader,
UnstructuredHTMLLoader,
UnstructuredMarkdownLoader,
)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_29076\3462575971.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import (

# %% [markdown]
# # Loading PDF File

# %%
myloader = PyPDFLoader(r"C:\Users\User\Desktop\myworkspace\sample_document.pdf")

# %%
mydocs = myloader.load()

# %%
mydocs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-04T16:55:50+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-04T16:55:50+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\User\\Desktop\\myworkspace\\sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly')]

# %%
# to check the metadata of the file
mydocs[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T16:55:50+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T16:55:50+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'C:\\Users\\User\\Desktop\\myworkspace\\sample_document.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
mydocs[0].page_content
# Out:
# 'LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly'

# %%
# to see the page content

print(mydocs[0].page_content)
# Out:
# LangChain PDF Loader Sample
# This PDF is used to demonstrate PyPDFLoader in LangChain.
# Refund Policy
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
# Support SLA
# Priority 1 tickets should receive a first response within 2 hours.
# Policy
# Owner
# Update Frequency
# Refund Policy
# Support
# Quarterly
# Leave Policy
# HR
# Yearly

# %% [markdown]
# # Loading Text File

# %%
# Loading sample text file into a variable textloader
textloader = TextLoader(r"C:\Users\User\Desktop\myworkspace\sampletext.txt")

# %%
txtdocs = textloader.load()
txtdocs
# Out:
# [Document(metadata={'source': 'C:\\Users\\User\\Desktop\\myworkspace\\sampletext.txt'}, page_content='LangChain Starter Parser Sample\n\nThis text file is used to demonstrate TextLoader.\n\nRAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.\n\nRefund Policy Example:\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.')]

# %%
print(txtdocs[0].page_content)
# Out:
# LangChain Starter Parser Sample
#
# This text file is used to demonstrate TextLoader.
#
# RAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.
#
# Refund Policy Example:
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.

# %% [markdown]
# # CSV File

# %%
myCSVdoc = CSVLoader(r"C:\Users\User\Desktop\myworkspace\sample_data.csv")

# %%
myData = myCSVdoc.load()

# %%
print(myData[0].page_content)
# Out:
# policy_id: P-001
# department: HR
# topic: Leave Policy
# details: Employees get 18 paid leaves per year.
# last_updated: 2026-01-10

# %% [markdown]
# # Json file Load

# %%
jsonloader = JSONLoader(r"C:\Users\User\Desktop\myworkspace\sample_data.json",jq_schema=".[]",text_content=False)

# %%
myjsonData = jsonloader.load()

# %% [markdown]
# # HTML Load

# %%
htmlLoader =  UnstructuredHTMLLoader(r"C:\Users\User\Desktop\myworkspace\sample_page.html")

# %%
htmlLoader.load()
# Out:
# [Document(metadata={'source': 'C:\\Users\\User\\Desktop\\myworkspace\\sample_page.html'}, page_content='Company Knowledge Base\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nSupport SLA\n\nPriority 1 tickets should receive a first response within 2 hours.\n\nChannel: Email\n\nChannel: Chat\n\nChannel: Phone')]

# %%
myHtmlData = htmlLoader.load()

# %%
print(myHtmlData[0].page_content)
# Out:
# Company Knowledge Base
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Support SLA
#
# Priority 1 tickets should receive a first response within 2 hours.
#
# Channel: Email
#
# Channel: Chat
#
# Channel: Phone

# %%
# or we can also use the below code to load the html file into a variable
print(htmlLoader.load()[0].page_content)
# Out:
# Company Knowledge Base
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Support SLA
#
# Priority 1 tickets should receive a first response within 2 hours.
#
# Channel: Email
#
# Channel: Chat
#
# Channel: Phone

# %% [markdown]
# # Document file Load

# %%
myDocsLoader= Docx2txtLoader(r"C:\Users\User\Desktop\myworkspace\sample_document.docx")

# %%
MyDocsData = myDocsLoader.load()

# %%
print(MyDocsData[0].page_content)
# Out:
# LangChain DOCX Loader Sample
#
# This document is used to demonstrate Docx2txtLoader in LangChain.
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Leave Policy
#
# Employees receive 18 paid leaves per year and 8 sick leaves per year.
#
# Simple Table
#
# Policy
#
# Owner
#
# Update Frequency
#
# Refund Policy
#
# Support
#
# Quarterly
#
# Leave Policy
#
# HR
#
# Yearly

# %% [markdown]
# # Mark down (.md) file Load

# %%
myMD =UnstructuredMarkdownLoader(r"C:\Users\User\Desktop\myworkspace\sample.md")

# %%
myMDFile = myMD.load()

# %%
print(myMDFile[0].page_content)
# Out:
# Enterprise RAG System: Complete Sample Markdown Document
#
# 1. Introduction
#
# Retrieval-Augmented Generation, commonly known as RAG, is a technique used to connect Large Language Models with external knowledge sources. Instead of depending only on the knowledge stored inside the model during training, RAG allows the system to retrieve relevant information from documents, databases, websites, or other sources at runtime.
#
# This makes RAG very useful for enterprise applications where the data is private, frequently changing, or too large to fit inside the model context directly.
#
# In simple terms:
#
# RAG does not train the model. RAG gives the model the right context before answering.
#
# 2. Why RAG is Needed
#
# Large Language Models are powerful, but they have limitations.
#
# 2.1 LLMs Do Not Know Private Data
#
# ...
