# %% [markdown]
# ### This model is trained on Google news dataset, it has 300 dimensions for each word vector
# -  This is the model used in old and currently outdated

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.downloader as api

# %%
# skip-gram
model = api.load('word2vec-google-news-300')

# %%
model['Mazhar']
# Out:
# array([-0.34960938,  0.31445312,  0.09863281, -0.16308594,  0.08349609,
#         0.33984375, -0.16796875, -0.23144531, -0.12207031,  0.1875    ,
#        -0.2578125 , -0.09082031, -0.16308594,  0.10498047, -0.25585938,
#        -0.13476562,  0.09375   , -0.390625  ,  0.13671875,  0.18359375,
#        -0.28320312, -0.13867188, -0.078125  ,  0.37109375, -0.140625  ,
#         0.01306152,  0.26953125,  0.18847656, -0.09228516, -0.43164062,
#        -0.30078125,  0.0168457 ,  0.46289062,  0.09863281, -0.07226562,
#         0.12304688, -0.06542969, -0.03491211, -0.08007812, -0.19433594,
#         0.14941406,  0.22070312, -0.13671875,  0.05493164,  0.0480957 ,
#        -0.11767578, -0.05322266, -0.23242188, -0.02929688, -0.05957031,
#        -0.046875  , -0.01080322,  0.40429688, -0.18652344, -0.16699219,
#         0.09912109, -0.09472656,  0.37890625, -0.11376953, -0.5625    ,
#        -0.04321289, -0.03955078, -0.16894531, -0.06225586, -0.08496094,
# ...

# %% [markdown]
# - this has created 300 objects

# %%
len(model['Mazhar'])
# Out:
# 300

# %%
print(model['Mazhar'])
print("Model has 300 object: ",len(model['Mazhar']))
# Out:
# [-0.34960938  0.31445312  0.09863281 -0.16308594  0.08349609  0.33984375
#  -0.16796875 -0.23144531 -0.12207031  0.1875     -0.2578125  -0.09082031
#  -0.16308594  0.10498047 -0.25585938 -0.13476562  0.09375    -0.390625
#   0.13671875  0.18359375 -0.28320312 -0.13867188 -0.078125    0.37109375
#  -0.140625    0.01306152  0.26953125  0.18847656 -0.09228516 -0.43164062
#  -0.30078125  0.0168457   0.46289062  0.09863281 -0.07226562  0.12304688
#  -0.06542969 -0.03491211 -0.08007812 -0.19433594  0.14941406  0.22070312
#  -0.13671875  0.05493164  0.0480957  -0.11767578 -0.05322266 -0.23242188
#  -0.02929688 -0.05957031 -0.046875   -0.01080322  0.40429688 -0.18652344
#  -0.16699219  0.09912109 -0.09472656  0.37890625 -0.11376953 -0.5625
#  -0.04321289 -0.03955078 -0.16894531 -0.06225586 -0.08496094  0.0546875
#   0.13964844  0.03979492  0.27929688 -0.27148438 -0.30859375 -0.02600098
#  -0.12060547  0.07275391 -0.078125   -0.09228516  0.08691406 -0.01409912
# ...

# %%
# this will show an error as we are passing multiple words -->KeyError: "Key 'I am Mazhar' not present", 
# skip gram accepts only one word at a time
model['I am Mazhar']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 3
#       1 # this will show an error as we are passing multiple words -->KeyError: "Key 'I am Mazhar' not present",
#       2 # skip gram accepts only one word at a time
# ----> 3 model['I am Mazhar']
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
# ...

# %%
model['men']
# Out:
# array([-4.78515625e-02,  1.66992188e-01,  7.81250000e-02,  2.10571289e-03,
#         2.25585938e-01, -2.25585938e-01, -2.09960938e-01, -3.73535156e-02,
#        -1.85546875e-02,  1.94335938e-01, -3.00292969e-02, -1.77734375e-01,
#         5.20019531e-02,  1.33789062e-01, -1.13769531e-01,  1.10351562e-01,
#        -3.27148438e-02,  2.89916992e-03,  9.88769531e-03,  9.27734375e-02,
#        -2.19726562e-01, -2.47802734e-02, -8.59375000e-02, -2.67578125e-01,
#        -2.51464844e-02, -2.55859375e-01, -1.61132812e-01,  2.53906250e-01,
#         5.24902344e-02, -1.00097656e-02,  1.82617188e-01,  7.61718750e-02,
#        -1.60980225e-03, -3.10058594e-02, -3.32031250e-02,  1.81640625e-01,
#        -3.88183594e-02, -1.83593750e-01, -8.64257812e-02,  2.20703125e-01,
#        -7.11059570e-03,  8.60595703e-03,  1.73828125e-01, -9.27734375e-02,
#         1.25000000e-01, -1.28906250e-01, -4.85839844e-02, -1.21093750e-01,
# ...

# %%
model.most_similar('Man')
# Out:
# [('Woman', 0.6939345002174377),
#  ('Boy', 0.5896925330162048),
#  ('Girl', 0.584598958492279),
#  ('Suspect', 0.5577560067176819),
#  ('Couple', 0.5528685450553894),
#  ('man', 0.5316051840782166),
#  ('Robber', 0.5315312743186951),
#  ('Teenager', 0.5161930322647095),
#  ('depicts_Michelangelo_Creation', 0.5148172378540039),
#  ('Policeman', 0.5136396884918213)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('soccer')
# Out:
# [('Soccer', 0.7622618675231934),
#  ('football', 0.7313547730445862),
#  ('basketball', 0.6810985207557678),
#  ('volleyball', 0.6647275686264038),
#  ('softball', 0.6443415284156799),
#  ('lacrosse', 0.6438060402870178),
#  ('water_polo', 0.6297686100006104),
#  ('hockey', 0.6270937323570251),
#  ('tennis', 0.6163383722305298),
#  ('futbol', 0.6026160717010498)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('Mazhar')
# Out:
# [('Waseem', 0.6975557804107666),
#  ('Hussain', 0.6847996711730957),
#  ('Majid', 0.6832634210586548),
#  ('Khurram', 0.6779667139053345),
#  ('Mohammad', 0.6769405603408813),
#  ('Latif', 0.6691622138023376),
#  ('Mohsin', 0.6675790548324585),
#  ('Hameed', 0.6669988036155701),
#  ('Syed', 0.6664249300956726),
#  ('Javed', 0.6664057970046997)]

# %%
model['MazharMohammed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model['MazharMohammed']
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)    444
#     445     """
# ...

# %%
model["MazharMohammed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model["MazharMohammed"]
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\User\Desktop\myworkspace\env_uv\Lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)    444
#     445     """
# ...

# %% [markdown]
# - the above is errored out becuase MazharMohammed is not available in the model -- "MazharMohammed" is not in the model's vocabulary. This is a Google News trained model, so it only knows common English words and named entities from news articles

# %%
"MazharMohammed" in model
# Out:
# False

# %%
'Mohammed' in model
# Out:
# True

# %%
model.most_similar('Mohammed')
# Out:
# [('Ahmed', 0.8453757762908936),
#  ('Mohammad', 0.8238286375999451),
#  ('Ibrahim', 0.8207249641418457),
#  ('Khalid', 0.7993230223655701),
#  ('Mohamed', 0.7979633808135986),
#  ('Muhammed', 0.7814116477966309),
#  ('Hamza', 0.7592103481292725),
#  ('Majid', 0.7564958930015564),
#  ('Hassan', 0.7463027238845825),
#  ('Sheikh', 0.7341278195381165)]
